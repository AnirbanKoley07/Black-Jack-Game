# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirbanKoley07/Black-Jack-Game/blob/main/Black_Jack_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
#creating the dack of cards
card_categories=['Hearts','Diamonds','clubs','spades']
card_list=['Ace','2','3','4','5','6','7','8','9','10','jack','Queen','King']
deck=[(card,category) for category in card_categories for card in card_list]

# %%
#Function to assign points for the specific cards
def card_value(card):
  if card[0]in ['jack','Queen','King']:
       return 10
  elif card[0]=='Ace':
    return 11
  else:
    return int(card[0])

# %%
import random
# we will use random.shuffle() to shuffle our deck of cards to maintain randomness
random.shuffle(deck)
player_card=[deck.pop(),deck.pop()]
dealer_card=[deck.pop(),deck.pop()]

# %%
while True:
    player_score = sum(card_value(card) for card in player_card)
    dealer_score = sum(card_value(card) for card in dealer_card)

    print("cards player has:", player_card)
    print("score of the player:", player_score)
    print("\n")

    choice = input('What do you want? ["play" to request another card, "stop" to stop]: ').lower()

    if choice == "play":
        new_card = deck.pop()
        player_card.append(new_card)

    elif choice == "stop":
        break

    else:
        print("Invalid choice. Please try again.")
        continue

    if player_score > 21:
        print("cards dealer has:", dealer_card)
        print("score of the dealer:", dealer_score)
        print("score of the player:", player_score)
        print("Dealer wins (player loses because score exceeded 21)")
        break
# Out:
# cards player has: [('4', 'clubs'), ('7', 'clubs')]
# score of the player: 11
#
#
# What do you want? ["play" to request another card, "stop" to stop]: play
# cards player has: [('4', 'clubs'), ('7', 'clubs'), ('King', 'clubs')]
# score of the player: 21
#
#
# What do you want? ["play" to request another card, "stop" to stop]: play
# cards player has: [('4', 'clubs'), ('7', 'clubs'), ('King', 'clubs'), ('9', 'clubs')]
# score of the player: 30
#
#
# What do you want? ["play" to request another card, "stop" to stop]: play
# cards dealer has: [('3', 'spades'), ('King', 'Hearts')]
# score of the dealer: 13
# score of the player: 30
# Dealer wins (player loses because score exceeded 21)

# %%
#dealer has to draw cards now
while dealer_score < 17:
    new_card = deck.pop()
    dealer_card.append(new_card)
    dealer_score += card_value(new_card)

print("Cards Dealer Has:", dealer_card)
print("Score Of The Dealer:", dealer_score)
print("\n")
# Out:
# Cards Dealer Has: [('3', 'spades'), ('King', 'Hearts'), ('3', 'clubs'), ('10', 'Diamonds')]
# Score Of The Dealer: 26

# %%
#decision wala code hai ye omggg who will win guess karna
if dealer_score > 21:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("Player wins (Dealer Loss Because Dealer Score is exceeding 21)")
elif player_score > dealer_score:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("Player wins (Player Has High Score than Dealer)")
elif dealer_score > player_score:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("Dealer wins (Dealer Has High Score than Player)")
else:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("It's a tie.")
# Out:
# Cards Dealer Has: [('3', 'spades'), ('King', 'Hearts'), ('3', 'clubs'), ('10', 'Diamonds')]
# Score Of The Dealer: 26
# Cards Player Has: [('4', 'clubs'), ('7', 'clubs'), ('King', 'clubs'), ('9', 'clubs'), ('2', 'clubs')]
# Score Of The Player: 30
# Player wins (Dealer Loss Because Dealer Score is exceeding 21)
